# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
# define procedure here
def check_input(test1):
  def check_input(test1): 
    count = 0

    for x in range(len(test1)):
        test1 = list(set(test1[x]))
#         toCheck 
        if sorted(test1) == sorted(test1[x]):
            count += 1

          
    if count is len(test1):
        return True
    return False

# %%
# run this block to test code after defining the procedure

test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]
        


print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false
# Out:
# None
# None
# None

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
import pandas as pd
url='https://raw.githubusercontent.com/Ahmad-Naeem8858/StudentMarkSheet.csv/main/StudentMarkSheet.csv'
df=pd.read_csv(url)
print(df)
print()
df.info()
print(sep='\n')
df.head()
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [200 rows x 4 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student name  200 non-null    object
#  1   Exam name     199 non-null    object
#  2   Exam date     200 non-null    object
# ...

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
import pandas as pd
url='https://raw.githubusercontent.com/Ahmad-Naeem8858/StudentMarkSheet.csv/main/StudentMarkSheet.csv'
df=pd.read_csv(url)
new_df = df.dropna()

print(new_df.to_string())
print()
print('number of rows containing null data')
df.isnull() .sum() .sum() # 4 rows in total
print()
print (df.count())

# subsetting df
print(df[df.isna().any(axis=1)])
# Out:
#            Student name    Exam name   Exam date  Marks
# 0          James Walker      Biology  05/06/2016   31.0
# 1         Velma Clemons      Biology  05/06/2016   43.0
# 2        Kibo Underwood      Biology  05/06/2016   81.0
# 3           Louis Mcgee      Biology  05/06/2016   11.0
# 4          Phyllis Paul      Biology  05/06/2016   18.0
# 5        Zenaida Decker      Biology  05/06/2016   55.0
# 6       Gillian Tillman      Biology  05/06/2016   38.0
# 7       Constance Boone      Biology  05/06/2016   16.0
# 8     Giselle Lancaster      Biology  05/06/2016   73.0
# 9      Kirsten Mcdowell      Biology  05/06/2016   16.0
# 10          Solomon Ray      Biology  05/06/2016   23.0
# 11        John Marshall      Biology  05/06/2016   55.0
# 12       Merrill Carney      Biology  05/06/2016   71.0
# 13     Hakeem Gillespie      Biology  05/06/2016   12.0
# 14         Hayden Boyer      Biology  05/06/2016   77.0
# 15       Griffin Mcleod      Biology  05/06/2016   19.0
# ...

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
df.loc[df['Student name'] == 'James Walker']
# Out:
#      Student name    Exam name   Exam date  Marks
# 0    James Walker      Biology  05/06/2016   31.0
# 42   James Walker    Chemistry  15/06/2016   61.0
# 71   James Walker  Mathematics  29/07/2016   23.0
# 150  James Walker      Physics  10/06/2016  100.0
# 180  James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
import numpy as np
mark_avg = np.array([
        
        df[df['Exam name'] == 'Biology']['Marks'].mean(),
        df[df['Exam name'] == 'Chemistry']['Marks'].mean(),
        df[df['Exam name'] == 'Mathematics']['Marks'].mean(),
        df[df['Exam name'] == 'Philosophy']['Marks'].mean(),
        df[df['Exam name'] == 'Physics']['Marks'].mean(),
        df[df['Exam name'] == 'Sociology']['Marks'].mean(),
        
        ])
print('biology','chemistry','mathematics','philosophy','physics','sociology')
print(mark_avg)
print()
# Out:
# biology chemistry mathematics philosophy physics sociology
# [47.89473684 50.57692308 48.97222222 47.27027027 51.76190476 56.02631579]

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
import matplotlib.pyplot as plt
exam_names=['biology','chemistry','maths','philosophy','physics','sociology']
plt.bar(exam_names,mark_avg)
plt.show()

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
import pandas as pd
url='https://raw.githubusercontent.com/Ahmad-Naeem8858/CatData/main/CatData.csv'
df=pd.read_csv(url)
new_df = df.dropna()

print(new_df.to_string())
print()
print('number of rows containing null data')
df.isnull() .sum() .sum()
# Out:
#      Tail Length (cm)  Mass (kg)
# 0                18.1      3.750
# 1                18.6      3.800
# 2                19.5      3.250
# 3                19.3      3.450
# 4                19.0      3.650
# 5                18.1      3.625
# 6                19.5      4.675
# 7                19.3      3.475
# 8                19.0      4.250
# 9                18.6      3.300
# 10               18.0      3.700
# 11               18.2      3.200
# 12               19.1      3.800
# 13               19.8      4.400
# 14               18.5      3.700
# 15               19.5      3.450
# 16               19.7      4.500
# 17               18.4      3.325
# 18               19.4      4.200
# 19               17.4      3.400
# 20               18.0      3.600
# 21               18.9      3.800
# 22               18.5      3.950
# 23               18.0      3.800
# 24               18.7      3.800
# 25               18.3      3.550
# 26               18.7      3.200
# ...

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
# dependant variable: 
#mass
# independant variable:
#tail length

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
#Main function to find the coefficients of Line:
def simple_linear_regression(input_feature,output):
    
    Xi = input_feature
    Yi = output
    
    #Total number of data points:
    n = len(Xi)
    
    #X bar:
    Xi_mean = Xi.mean()
    
    #Y bar:
    Yi_mean = Yi.mean()
    
    #Sum of X:
    S_Xi = (Xi).sum()
    
    #Sum of Y:
    S_Yi = (Yi).sum()
    
    #Sum of (X*Y) multiplied by n:
    S_XiYi = ((Xi*Yi).sum())*n
    
    #Sum of X*Sum of Y:
    S_Xi_S_Yi = S_Xi*S_Yi
    
    #Sum of (X*X) multiplied by n:
    S_XiXi = ((Xi*Xi).sum())*n
    
    #Square of sum of X:
    S_Xi_Square = S_Xi*S_Xi
    
    #SLope:
    slope = (S_XiYi- S_Xi_S_Yi) / (S_XiXi-S_Xi_Square)
    
    #Intercept:
    intercept = Yi_mean - slope * Xi_mean
    
    return slope, intercept

ran = int(len(df)*0.8)
train = df[:ran]
test = df[ran:]

actual_slope, actual_intercept = simple_linear_regression( train['Mass (kg)'],train['Tail Length (cm)'])

from sklearn.linear_model import LinearRegression

train_x = np.array(train[['Mass (kg)']])
train_y = np.array(train[['Tail Length (cm)']])

reg = LinearRegression().fit(train_x, train_y)

coeff = reg.coef_
intercept = reg.intercept_

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
print('Slope', coeff)
print('Y-intercept', intercept)

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
plt.scatter(train['Mass (kg)'], train['Tail Length (cm)'], c='grey')
plt.plot(train_x, coeff[0]*train_x + intercept, color='red')
plt.xlabel('Mass (kg)'); plt.ylabel('Tail Length (cm)')
plt.show()
